# %%
import pandas as pd

# %%
df = pd.read_csv('data-2263-2025-06-09.csv', sep=';')

# %%
# Настройка отображения всех столбцов
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#     global_id                                            OrgType  \
# 0   global_id                    Тип образовательной организации
# 1  2693941064  организация дополнительного профессионального ...
# 2  2693941190  организация дополнительного профессионального ...
# 3  2707620431       профессиональная образовательная организация
# 4  2707621917       профессиональная образовательная организация
#
#   ReorganizationStatus        KPP      LicensingAndAccreditation  \
# 0   Статус организации        КПП  Лицензирование и аккредитация
# 1          действующее  771301001                    nested data
# 2          действующее  770101001                    nested data
# 3          действующее  771601001                    nested data
# 4          действующее  772101001                    nested data
#
#             OGRN              LegalOrganization              Subordination  \
# 0           ОГРН  Организационно-правовая форма                 Подчинение
# 1  1027700566761                     автономное  Городское подчинение ДОНМ
# 2  1057707018192                     автономное  Городское подчинение ДОНМ
# 3  1057716005676                      бюджетное  Городское подчинение ДОНМ
# 4  1037739525031                      бюджетное  Городское подчинение ДОНМ
#
#                         ChiefName  \
# 0                ФИО руководителя
# 1    Айгунова Ольга Александровна
# 2  Тихомирова Ирина Станиславовна
# 3    Лунькин Александр Николаевич
# 4       Курачёва Ирина Михайловна
#
#                                         LegalAddress         PublicPhone  \
# 0                                  Юридический адрес  Контактный телефон
# 1       127422, г. Москва, Тимирязевская улица, д.36         nested data
# 2  105082, г. Москва, ул. Бакунинская, д. 55, стр. 4         nested data
# 3          129337, г. Москва, Хибинский проезд, д.10         nested data
# 4  109457, г. Москва, ул. Федора Полетаева, д. 2,...         nested data
#
#                      Email         WebSite  \
# 0  Адрес электронной почты            Сайт
# 1              nested data  corp-univer.ru
# 2              nested data        mcrpo.ru
# 3              nested data   kst.mskobr.ru
# 4              nested data   mpk.mskobr.ru
#
#                                    EducationPrograms     EducationalServices  \
# 0                          Образовательные программы  Образовательные услуги
# 1  Профессиональное образование | высшее образова...             nested data
# 2  Дополнительное образование | дополнительное об...             nested data
# 3  Профессиональное обучение # Профессиональное о...             nested data
# 4  Профессиональное обучение # Профессиональное о...             nested data
#
#            NumberofStudentsInOO      TheContingentOfPreschoolersStudyingOO  \
# 0  Количество обучающихся по ОО  Контингент обучающихся дошкольников по ОО
# 1                   nested data                                nested data
# 2                   nested data                                nested data
# 3                   nested data                                nested data
# 4                   nested data                                nested data
#
#      IDEKIS                                           FullName  \
# 0  Код ЕКИС                                Полное наименование
# 1     14494  Государственное автономное образовательное учр...
# 2     14506  Государственное автономное образовательное учр...
# 3     11688  Государственное бюджетное профессиональное обр...
# 4     14554  Государственное бюджетное профессиональное обр...
#
#                                            ShortName Number  \
# 0                           Сокращённое наименование  Номер
# 1               ГАОУ ДПО «Корпоративный университет»    NaN
# 2                                     ГАОУ ДПО МЦРПО    NaN
# 3                                          ГБПОУ КСТ    NaN
# 4  ГБПОУ «Московский педагогический колледж» , ГБ...    NaN
#
#   InstitutionsAddresses         INN SupplementaryClassesAndGroups  \
# 0     Адреса учреждения         ИНН               Кружки и секции
# 1           nested data  7714239823                   nested data
# 2           nested data  7707329480                   nested data
# 3           nested data  7716237691                   nested data
# 4           nested data  7721222323                   nested data
#
#                                              geoData  \
# 0                                            geoData
# 1  {coordinates=[[[[37.539544671, 55.799821354], ...
# 2  {coordinates=[[[[37.687809497, 55.778008355], ...
# 3  {coordinates=[[[[37.678901702, 55.854864834], ...
# 4  {coordinates=[[[[37.773530781, 55.714432364], ...
#
#                                       geodata_center  Unnamed: 26
# 0                                     geodata_center          NaN
# 1  {coordinates=[37.592871367, 55.74331966], type...          NaN
# 2  {coordinates=[37.688373846, 55.77807037], type...          NaN
# 3  {coordinates=[37.680229083, 55.856535836], typ...          NaN
# 4  {coordinates=[37.774123428, 55.714665048], typ...          NaN

# %%
df.iloc[2]['geoData']
# Out:
# '{coordinates=[[[[37.687809497, 55.778008355], [37.688003212, 55.778102216], [37.688064307, 55.77806199], [37.688225339, 55.778143743], [37.68822971, 55.778203619], [37.688286334, 55.778232112], [37.688286334, 55.778278204], [37.688381702, 55.778324296], [37.688682705, 55.778134061], [37.688684195, 55.778078751], [37.688556045, 55.778016736], [37.688518793, 55.778037687], [37.688041955, 55.777801358], [37.687816948, 55.777944664], [37.687809497, 55.778008355]]], [[[37.711001873, 55.762921204], [37.71116066, 55.762860842], [37.711166382, 55.762804503], [37.711119175, 55.762771505], [37.711335182, 55.762686192], [37.711426735, 55.762759433], [37.711582661, 55.762698265], [37.711584091, 55.762639512], [37.711366654, 55.762460837], [37.710780144, 55.762687802], [37.710783005, 55.762742531], [37.711001873, 55.762921204]]]], type=MultiPolygon}'

# %%
df.iloc[2]['geodata_center']
# Out:
# '{coordinates=[37.688373846, 55.77807037], type=Point}'

# %%
df[df['FullName'].str.contains('еникс')]['FullName'].head()
# Out:
# 155    Государственное бюджетное общеобразовательное ...
# Name: FullName, dtype: object

# %%
df[df['FullName'].str.contains('еникс')]['FullName'].tolist()
# Out:
# ['Государственное бюджетное общеобразовательное учреждение города Москвы «Школа № 1798 «Феникс»']
