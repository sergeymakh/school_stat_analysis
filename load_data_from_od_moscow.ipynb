# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db_connection_str = 'postgresql+psycopg2://postgres:postgres@localhost:5432/schooldata'
engine = create_engine(db_connection_str)

# %% [markdown]
# #### Образовательные учреждения города Москвы
# Образовательные учреждения города Москвы: https://data.mos.ru/opendata/2263?isDynamic=false
# Файл: data-2263-2025-08-25.csv

# %%
df = pd.read_csv('data-2263-2025-08-25.csv', sep=';', skiprows=1)
df = df.drop('Unnamed: 26', axis=1)

# %%
df.to_sql(name='schools', con=engine, schema='schooldata', if_exists='replace', index=False)
# Out:
# 572

# %% [markdown]
# #### Победители олимпиад
# Победители олимпиад: https://data.mos.ru/opendata/1093?isDynamic=false
# Файл: data-1093-2025-09-01.csv

# %%
df = pd.read_csv('data-1093-2025-09-01.csv', sep=';', skiprows=1)
df = df.drop('Unnamed: 10', axis=1)

# %%
df.to_sql(name='olimpics_winners', con=engine, schema='schooldata', if_exists='replace', index=False)
# Out:
# 50

# %%
# Настройка отображения всех столбцов
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                      Полное официальное наименование  \
# 0  Государственное бюджетное общеобразовательное ...
# 1  Государственное бюджетное общеобразовательное ...
# 2  Государственное бюджетное общеобразовательное ...
# 3  Государственное бюджетное образовательное учре...
# 4  Государственное бюджетное образовательное учре...
#
#     Сокращенное наименование            Тип олимпиады  Этап  Класс  \
# 0  ГБОУ лицей «Вторая школа»  Всероссийская олимпиада   3.0     11
# 1  ГБОУ лицей «Вторая школа»  Всероссийская олимпиада   3.0     11
# 2  ГБОУ лицей «Вторая школа»  Всероссийская олимпиада   3.0     10
# 3              ГБОУ СОШ № 26  Всероссийская олимпиада   4.0     11
# 4              ГБОУ СОШ № 26  Всероссийская олимпиада   3.0     11
#
#                               Наименование олимпиады  \
# 0  Всероссийская олимпиада школьников по английск...
# 1  Всероссийская олимпиада школьников по английск...
# 2  Всероссийская олимпиада школьников по английск...
# ...

# %%
df.columns
# Out:
# Index(['Полное официальное наименование', 'Сокращенное наименование',
#        'Тип олимпиады', 'Этап', 'Класс', 'Наименование олимпиады',
#        'Профиль олимпиады', 'Статус (победитель / призёр)',
#        'Год участия в олимпиаде', 'global_id', 'Unnamed: 10'],
#       dtype='object')
