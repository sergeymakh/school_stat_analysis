# %%
import pandas as pd

# %%
import csv

# %%
df = pd.read_csv('data-2263-2025-08-25.csv', sep=';')

# %%
# Настройка отображения всех столбцов
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#     global_id                                       OrgType  \
# 0   global_id               Тип образовательной организации
# 1  2707620431  профессиональная образовательная организация
# 2  2707621917  профессиональная образовательная организация
# 3  2707621993  профессиональная образовательная организация
# 4  2720796316  профессиональная образовательная организация
#
#   ReorganizationStatus        KPP      LicensingAndAccreditation  \
# 0   Статус организации        КПП  Лицензирование и аккредитация
# 1          действующее  771601001                    nested data
# 2          действующее  772101001                    nested data
# 3          действующее  774301001                    nested data
# 4          действующее  772401001                    nested data
#
#             OGRN              LegalOrganization              Subordination  \
# 0           ОГРН  Организационно-правовая форма                 Подчинение
# 1  1057716005676                      бюджетное  Городское подчинение ДОНМ
# 2  1037739525031                      бюджетное  Городское подчинение ДОНМ
# 3  1057743026461                      бюджетное  Городское подчинение ДОНМ
# 4  1037739222070                      бюджетное  Городское подчинение ДОНМ
#
#                       ChiefName  \
# 0              ФИО руководителя
# 1  Лунькин Александр Николаевич
# 2     Курачёва Ирина Михайловна
# 3   Сидоренко Николай Андреевич
# 4     Седова Наталья Николаевна
#
#                                         LegalAddress         PublicPhone  \
# 0                                  Юридический адрес  Контактный телефон
# 1          129337, г. Москва, Хибинский проезд, д.10         nested data
# 2  109457, г. Москва, ул. Федора Полетаева, д. 2,...         nested data
# 3          125080, г. Москва, Светлый проезд, дом 2а         nested data
# 4  115569, г. Москва, Шипиловский проезд, дом 37,...         nested data
#
#                      Email                      WebSite  \
# 0  Адрес электронной почты                         Сайт
# 1              nested data                kst.mskobr.ru
# 2              nested data                mpk.mskobr.ru
# 3              nested data          college57.mskobr.ru
# 4              nested data  collegetsaritsyno.mskobr.ru
#
#                                    EducationPrograms     EducationalServices  \
# 0                          Образовательные программы  Образовательные услуги
# 1  Профессиональное обучение # Профессиональное о...             nested data
# 2  Профессиональное обучение # Профессиональное о...             nested data
# 3  Профессиональное обучение # Профессиональное о...             nested data
# 4  Профессиональное образование | среднее професс...             nested data
#
#            NumberofStudentsInOO      TheContingentOfPreschoolersStudyingOO  \
# 0  Количество обучающихся по ОО  Контингент обучающихся дошкольников по ОО
# 1                   nested data                                nested data
# 2                   nested data                                nested data
# 3                   nested data                                nested data
# 4                   nested data                                nested data
#
#      IDEKIS                                           FullName  \
# 0  Код ЕКИС                                Полное наименование
# 1     11688  Государственное бюджетное профессиональное обр...
# 2     14554  Государственное бюджетное профессиональное обр...
# 3     13443  Государственное бюджетное профессиональное обр...
# 4     11708  Государственное бюджетное профессиональное обр...
#
#                                            ShortName Number  \
# 0                           Сокращённое наименование  Номер
# 1                                          ГБПОУ КСТ    NaN
# 2  ГБПОУ «Московский педагогический колледж» , ГБ...    NaN
# 3                     ГБПОУ ТПСК им. В.М. Максимчука    NaN
# 4                           ГБПОУ колледж «Царицыно»    NaN
#
#   InstitutionsAddresses         INN SupplementaryClassesAndGroups  \
# 0     Адреса учреждения         ИНН               Кружки и секции
# 1           nested data  7716237691                   nested data
# 2           nested data  7721222323                   nested data
# 3           nested data  7743085744                   nested data
# 4           nested data  7737057354                   nested data
#
#                                              geoData  \
# 0                                            geoData
# 1  {coordinates=[[[[37.67924019, 55.855094362], [...
# 2  {coordinates=[[[[37.773467204, 55.714584323], ...
# 3  {coordinates=[[[[37.631574066, 55.680368484], ...
# 4  {coordinates=[[[[37.695848768, 55.61318208], [...
#
#                                       geodata_center  Unnamed: 26
# 0                                     geodata_center          NaN
# 1  {coordinates=[37.680189359, 55.856497466], typ...          NaN
# 2  {coordinates=[37.774186046, 55.71463069], type...          NaN
# 3  {coordinates=[37.608620707, 55.679963725], typ...          NaN
# 4  {coordinates=[37.715097715, 55.623445754], typ...          NaN

# %%
df[['global_id', 'OrgType', 'LegalOrganization', 'LegalAddress', 'ShortName', 'geodata_center']].head()
# Out:
#     global_id                                       OrgType  \
# 0   global_id               Тип образовательной организации
# 1  2707620431  профессиональная образовательная организация
# 2  2707621917  профессиональная образовательная организация
# 3  2707621993  профессиональная образовательная организация
# 4  2720796316  профессиональная образовательная организация
#
#                LegalOrganization  \
# 0  Организационно-правовая форма
# 1                      бюджетное
# 2                      бюджетное
# 3                      бюджетное
# 4                      бюджетное
#
#                                         LegalAddress  \
# 0                                  Юридический адрес
# 1          129337, г. Москва, Хибинский проезд, д.10
# 2  109457, г. Москва, ул. Федора Полетаева, д. 2,...
# 3          125080, г. Москва, Светлый проезд, дом 2а
# 4  115569, г. Москва, Шипиловский проезд, дом 37,...
#
#                                            ShortName  \
# 0                           Сокращённое наименование
# 1                                          ГБПОУ КСТ
# 2  ГБПОУ «Московский педагогический колледж» , ГБ...
# 3                     ГБПОУ ТПСК им. В.М. Максимчука
# 4                           ГБПОУ колледж «Царицыно»
#
#                                       geodata_center
# 0                                     geodata_center
# 1  {coordinates=[37.680189359, 55.856497466], typ...
# 2  {coordinates=[37.774186046, 55.71463069], type...
# 3  {coordinates=[37.608620707, 55.679963725], typ...
# 4  {coordinates=[37.715097715, 55.623445754], typ...

# %%
df.iloc[2]['geodata_center']
# Out:
# '{coordinates=[[[[37.687809497, 55.778008355], [37.688003212, 55.778102216], [37.688064307, 55.77806199], [37.688225339, 55.778143743], [37.68822971, 55.778203619], [37.688286334, 55.778232112], [37.688286334, 55.778278204], [37.688381702, 55.778324296], [37.688682705, 55.778134061], [37.688684195, 55.778078751], [37.688556045, 55.778016736], [37.688518793, 55.778037687], [37.688041955, 55.777801358], [37.687816948, 55.777944664], [37.687809497, 55.778008355]]], [[[37.711001873, 55.762921204], [37.71116066, 55.762860842], [37.711166382, 55.762804503], [37.711119175, 55.762771505], [37.711335182, 55.762686192], [37.711426735, 55.762759433], [37.711582661, 55.762698265], [37.711584091, 55.762639512], [37.711366654, 55.762460837], [37.710780144, 55.762687802], [37.710783005, 55.762742531], [37.711001873, 55.762921204]]]], type=MultiPolygon}'

# %%
df.iloc[2]['geodata_center']
# Out:
# '{coordinates=[37.688373846, 55.77807037], type=Point}'

# %%
df[df['FullName'].str.contains('еникс')]['FullName'].head()
# Out:
# 155    Государственное бюджетное общеобразовательное ...
# Name: FullName, dtype: object

# %%
df[df['FullName'].str.contains('еникс')]['FullName'].tolist()
# Out:
# ['Государственное бюджетное общеобразовательное учреждение города Москвы «Школа № 1798 «Феникс»']

# %%
import ast

# %%
with open('data-2263-2025-08-25.csv', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile, delimiter=';')
        next(reader)
        for row in reader:
            
            coordinates_str = row['geodata_center']
            coordinates_dict = coordinates_str.split('=')[1].split(']')[0] + ']'
            print(coordinates_dict)
            break
# Out:
# [37.680189359, 55.856497466]
